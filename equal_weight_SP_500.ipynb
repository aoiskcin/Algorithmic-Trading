# %% [markdown]
# # Equal-Weight S&P 500 Index Fund
#
# ## Introduction & Library Imports
#
# The objective of this core engineering module is to build an automated, programmatic asset-allocation engine. The application ingests a dynamic, user-specified portfolio valuation and algorithmically calculates the optimized integer-based share distribution required to construct a mathematically precise equal-weight replication of the S&P 500 index.
#
# ## Library Imports
#
# The first thing we need to do is import the open-source software libraries that we'll be using in this tutorial.

# %%
import numpy as np
import pandas as pd
import requests
import xlsxwriter
import math
import yfinance as yf
import time

# %% [markdown]
# ## Index Constituent Ingestion
#
# In a production environment, index adjustments are managed via a live enterprise pipeline connected directly to index providers (e.g., S&P Dow Jones Indices). For this standalone workstation implementation, the pipeline ingests a local, standardized CSV manifest (sp_500_stocks.csv) representing the baseline index constituents to seed the execution array."

# %%
stocks = pd.read_csv('sp_500_stocks.csv')
ticker_list = stocks["Ticker"].tolist()

# %% [markdown]
# ## Architectural API Migration Note
#
# The baseline tutorial architecture originally utilized the legacy IEX Cloud endpoint layout. Following the full deprecation and retirement of that service, this data engineering pipeline was fully refactored to query real-time market cap arrays and financial vectors natively through the yfinance API engine, optimizing network reliability and eliminating legacy token dependencies."

# %%
import pandas as pd
import yfinance as yf

print("Initializing High-Volume Ingestion Matrix...")

# 1. Execute a single, vectorized batch query for all tickers simultaneously
# This reduces network I/O overhead and avoids rate-limiting blocks
batch_data = yf.download(ticker_list, period="1d", group_by="ticker", progress=True)

# 2. Stage a vector to compile structured record nodes rapidly
parsed_records = []

print("\nProcessing and sanitizing financial vectors...")

for ticker in ticker_list:
    try:
        # Isolate the data block for the target security symbol
        if ticker in batch_data.columns.levels[0]:
            ticker_df = batch_data[ticker]
            
            # Extract closing price safely from the most recent historical matrix row
            if not ticker_df.empty:
                price = float(ticker_df['Close'].iloc[-1])
                
                # Retrieve structural market cap from the Ticker metadata engine
                market_cap = yf.Ticker(ticker).info.get('marketCap', None)
                
                # Append cleansed structural nodes to our array staging area
                parsed_records.append({
                    "Ticker": ticker,
                    "Stock Price": price,
                    "Market Capitalization": market_cap,
                    "Number of Shares to Buy": "N/A"
                })
    except Exception as e:
        # Gracefully trap structural missing elements without crashing execution
        continue

# 3. Instantiate the production DataFrame using structured records arrays
final_dataframe = pd.DataFrame(parsed_records)
print(f"Data ingestion complete! Target matrix established with {len(final_dataframe)} active constituents.")
final_dataframe
# Out:
# [*                      2%                       ]  11 of 505 completed
# Initializing High-Volume Ingestion Matrix...
# [***                    7%                       ]  36 of 505 completed$GPS: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [****                   9%                       ]  46 of 505 completed$HFC: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [****                   9%                       ]  47 of 505 completed$K: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [*****                 10%                       ]  48 of 505 completed$WBA: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [*******               15%                       ]  76 of 505 completed$VAR: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [********              17%                       ]  86 of 505 completed$WLTW: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# $FLT: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [********              17%                       ]  88 of 505 completed$RE: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [************          24%                       ]  119 of 505 completed$CTXS: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [************          25%                       ]  127 of 505 completed$CXO: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [************          25%                       ]  128 of 505 completed$ABC: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [*************         27%                       ]  137 of 505 completed$COG: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [*************         27%                       ]  138 of 505 completed$ATVI: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [*************         28%                       ]  139 of 505 completed$ABMD: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**************        29%                       ]  148 of 505 completed$ALXN: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [***************       31%                       ]  158 of 505 completed$MRO: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [***************       31%                       ]  159 of 505 completed$FBHS: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [****************      34%                       ]  170 of 505 completed$JNPR: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [****************      34%                       ]  171 of 505 completed$HBI: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [******************    38%                       ]  194 of 505 completed$VIAC: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [********************  41%                       ]  205 of 505 completed$FLIR: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [********************* 43%                       ]  215 of 505 completed$MXIM: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************45%                       ]  225 of 505 completed$WRK: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************47%                       ]  235 of 505 completed$HES: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# $ETFC: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************47%                       ]  236 of 505 completed$IPG: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************52%                       ]  261 of 505 completed$HOLX: possibly delisted; no price data found  (period=1d)
# [**********************53%                       ]  270 of 505 completed$TIF: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************57%**                     ]  287 of 505 completed$PXD: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************57%**                     ]  288 of 505 completed$BRK.B: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************57%**                     ]  289 of 505 completed$KSU: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************57%**                     ]  290 of 505 completed$DISCA: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************61%****                   ]  309 of 505 completed$NBL: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************61%****                   ]  310 of 505 completed$ANTM: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************62%*****                  ]  311 of 505 completed$SIVB: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************66%*******                ]  331 of 505 completed$CERN: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************66%*******                ]  332 of 505 completed$CMA: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************68%********               ]  342 of 505 completed$MYL: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************70%*********              ]  351 of 505 completed$DRE: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************70%*********              ]  352 of 505 completed$PBCT: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************72%**********             ]  362 of 505 completed$DISCK: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************72%**********             ]  363 of 505 completed$NLSN: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************74%***********            ]  373 of 505 completed$FRC: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************76%***********            ]  383 of 505 completed$MMC: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************76%***********            ]  384 of 505 completed$TWTR: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************78%************           ]  396 of 505 completed$XLNX: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************88%*****************      ]  445 of 505 completed$CTL: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************89%******************     ]  450 of 505 completed$SEE: possibly delisted; no price data found  (period=1d)
# [**********************90%******************     ]  456 of 505 completed$BLL: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************90%******************     ]  457 of 505 completed$ANSS: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************91%*******************    ]  460 of 505 completed$BF.B: possibly delisted; no price data found  (period=1d)
# [**********************94%********************   ]  477 of 505 completed$NLOK: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************95%*********************  ]  478 of 505 completed$PEAK: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************97%********************** ]  488 of 505 completed$PKI: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************98%********************** ]  497 of 505 completed$DISH: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [**********************99%***********************]  500 of 505 completed$DFS: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [*********************100%***********************]  505 of 505 completed
#
# 56 Failed downloads:
# ['GPS', 'HFC', 'K', 'WBA', 'VAR', 'WLTW', 'FLT', 'RE', 'CTXS', 'CXO', 'ABC', 'COG', 'ATVI', 'ABMD', 'ALXN', 'MRO', 'FBHS', 'JNPR', 'HBI', 'VIAC', 'FLIR', 'MXIM', 'WRK', 'HES', 'ETFC', 'IPG', 'TIF', 'PXD', 'BRK.B', 'KSU', 'DISCA', 'NBL', 'ANTM', 'SIVB', 'CERN', 'CMA', 'MYL', 'DRE', 'PBCT', 'DISCK', 'NLSN', 'FRC', 'MMC', 'TWTR', 'XLNX', 'CTL', 'BLL', 'ANSS', 'NLOK', 'PEAK', 'PKI', 'DISH', 'DFS']: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# ['HOLX', 'SEE', 'BF.B']: possibly delisted; no price data found  (period=1d)
# Processing and sanitizing financial vectors...
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: ANSS"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: CMA"}}}

# %% [markdown]
# ## Algorithmic Allocation Matrix
#
# Cleanses the real-time pricing dataframe by filtering missing elements, determines individual target capital allocations per stock based on the dynamic portfolio valuation input, and applies a strict mathematical floor calculation (math.floor) to ensure allocations are limited to tradable, whole integer-based share counts."

# %%
#get someones value of their portfolio
portfolio_size = input('Enter the value of your portfolio:')

#force input to be a float variable
try:
    val = float(portfolio_size)
except ValueError:
    print("That's not a number! \nPlease try again:")
    portfolio_size = input('Enter the value of your portfolio:')
    val = float(portfolio_size)

#if a string is input twice, an error will occur

# %%
import math

#Clean up the dataframe by dropping any row that has a blank (NaN) Stock Price
final_dataframe = final_dataframe.dropna(subset=['Stock Price'])

#Run your position size calculation
position_size = val / len(final_dataframe.index)

#Loop through and calculate the number of shares securely using the remaining index labels
for i in final_dataframe.index:
    final_dataframe.loc[i, 'Number of Shares to Buy'] = math.floor(position_size / final_dataframe.loc[i, 'Stock Price'])

#View your updated dataframe
final_dataframe

#math.floor is to round down in the case that brokers don't accpet fractional trading

# %% [markdown]
# ## Automated Executive Sheet Compiling
#
# Utilizes the XlsxWriter compiler engine to override default unformatted spreadsheet templates. This process maps the raw dataframe into a highly polished, production-ready spreadsheet.
#
# Workbook Initialization: Establishes the underlying file writing stream targets."

# %%
writer = pd.ExcelWriter('recommended trades.xlsx', engine = 'xlsxwriter')
final_dataframe.to_excel(writer, 'Recommended Trades', index = False)

#using pandas library and not xlsxwriter as pandas is tightly integrated to excel
#the engine = 'xlsxwriter' may seem redundant but the library can be used to save XML files hence need to specify

# %% [markdown]
# ## UI/UX Formatting Blobs
#
# Establishes explicit structural formats, assigning custom hex values (#0a0a23 background / #ffffff foreground text matrices), structural cell borders, and currency masks.
#
# DRY-Compliant Layout Automation: To respect the 'Don't Repeat Yourself' (DRY) architectural paradigm, column tracking and custom typography applications are compiled dynamically through key-value loops rather than manual cell formatting statements."

# %%
background_color = '#0a0a23'
font_color = '#ffffff'

string_format = writer.book.add_format(
    {
        'font_color': font_color,
        'bg_color': background_color,
        'border': 1
    }
)

dollar_format = writer.book.add_format(
    {
        'num_format': '$0.00',
        'font_color': font_color,
        'bg_color': background_color,
        'border': 1
    }
)

integer_format = writer.book.add_format(
    {
        'num_format': '0',
        'font_color': font_color,
        'bg_color': background_color,
        'border': 1
    }
)

# %%
# writer.sheets['Recommended Trades'].set_column('A:A', 18, string_format)
# writer.sheets['Recommended Trades'].set_column('B:B', 18, string_format)
# writer.sheets['Recommended Trades'].set_column('C:C', 18, string_format)
# writer.sheets['Recommended Trades'].set_column('D:D', 18, string_format)
# writer.close()

# writer.sheets['Recommended Trades'].write('A1', 'Ticker', string_format)
# writer.sheets['Recommended Trades'].write('B1', 'Stock Price', dollar_format)
# writer.sheets['Recommended Trades'].write('C1', 'Market Capitalization', dollar_format)
# writer.sheets['Recommended Trades'].write('D1', 'Number of Shares to Buy', integer_format)

# %%
column_formats = {
    'A': ['Ticker', string_format],
    'B': ['Stock Price', dollar_format],
    'C': ['Market Capitalization', dollar_format],
    'D': ['Number of Share to Buy', integer_format]
}

#keys method returns all of the variables on top
for column in column_formats.keys():
    writer.sheets['Recommended Trades'].set_column(f'{column}:{column}', 18, column_formats[column][1])
    writer.sheets['Recommended Trades'].write(f'{column}1', column_formats[column][0], column_formats[column][1])

# %% [markdown]
# ## Data Buffer Finalization
#
# Explicitly executes writer.close() to close data storage buffers, seal the file architecture, and release operating system file-system locks cleanly.

# %%
writer.close()
